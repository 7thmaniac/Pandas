# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(columns='date')
# Out:
#           city                     temperature                   humidity  \
# date  5/1/2017  5/2/2017  5/3/2017    5/1/2017 5/2/2017 5/3/2017 5/1/2017
# 0     new york       NaN       NaN        65.0      NaN      NaN     56.0
# 1          NaN  new york       NaN         NaN     66.0      NaN      NaN
# 2          NaN       NaN  new york         NaN      NaN     68.0      NaN
# 3       mumbai       NaN       NaN        75.0      NaN      NaN     80.0
# 4          NaN    mumbai       NaN         NaN     78.0      NaN      NaN
# 5          NaN       NaN    mumbai         NaN      NaN     82.0      NaN
# 6      beijing       NaN       NaN        80.0      NaN      NaN     26.0
# 7          NaN   beijing       NaN         NaN     77.0      NaN      NaN
# 8          NaN       NaN   beijing         NaN      NaN     79.0      NaN
#
#
# date 5/2/2017 5/3/2017
# 0         NaN      NaN
# 1        58.0      NaN
# 2         NaN     60.0
# 3         NaN      NaN
# 4        83.0      NaN
# ...

# %%
df = pd.read_csv("Weather.csv")
df.pivot(index='city', columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df = pd.read_csv("Weather.csv")
df.pivot(index='date', columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='date', columns='city', values='humidity')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df.pivot(index='city', columns='date', values='humidity')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot(index='date', columns='city', values='temperature')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       80      75        65
# 5/2/2017       77      78        66
# 5/3/2017       79      82        68

# %%
df.pivot(index='city', columns='date', values='temperature')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         80        77        79
# mumbai          75        78        82
# new york        65        66        68

# %%
df.pivot(index='date', columns='city', values=['temperature', 'humidity'])
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index='city', columns='date', values=['temperature', 'humidity'])
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df = pd.read_csv("Weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='date', columns='city', margins=True)
# Out:
#          humidity                 temperature
# city       mumbai new york    All      mumbai new york     All
# date
# 5/1/2017     81.5     55.0  68.25       76.50     63.0  69.750
# 5/2/2017     55.5     61.0  58.25       81.00     71.0  76.000
# All          68.5     58.0  63.25       78.75     67.0  72.875

# %%
df.pivot_table(index='city', columns='date', margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df.pivot_table(index='city', columns='date', margins=True, aggfunc='sum')
# Out:
#          humidity               temperature
# date     5/1/2017 5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %%
df.pivot_table(index='date', columns='city', margins=True, aggfunc='sum')
# Out:
#          humidity               temperature
# city       mumbai new york  All      mumbai new york  All
# date
# 5/1/2017      163      110  273         153      126  279
# 5/2/2017      111      122  233         162      142  304
# All           274      232  506         315      268  583

# %%
df.pivot_table(index='city', columns='date', margins=True, aggfunc='sum', values='temperature')
# Out:
# date      5/1/2017  5/2/2017  All
# city
# mumbai         153       162  315
# new york       126       142  268
# All            279       304  583

# %%
df.pivot_table(index='date', columns='city', margins=True, aggfunc='sum', values='temperature')
# Out:
# city      mumbai  new york  All
# date
# 5/1/2017     153       126  279
# 5/2/2017     162       142  304
# All          315       268  583

# %%
df.pivot_table(index='date', columns='city', margins=True, aggfunc='sum', values='humidity')
# Out:
# city      beijing  mumbai  new york  All
# date
# 5/1/2017       26      80        56  162
# 5/2/2017       30      83        58  171
# 5/3/2017       35      85        60  180
# All            91     248       174  513

# %%
df.pivot_table(index='date', columns='city', margins=True, aggfunc='sum', values=['humidity', 'temperature'])
# Out:
#          humidity                      temperature
# city      beijing mumbai new york  All     beijing mumbai new york  All
# date
# 5/1/2017       26     80       56  162          80     75       65  220
# 5/2/2017       30     83       58  171          77     78       66  221
# 5/3/2017       35     85       60  180          79     82       68  229
# All            91    248      174  513         236    235      199  670

# %%
df = pd.read_csv("Weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df.pivot_table(index=pd.Grouper(freq='ME',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667
